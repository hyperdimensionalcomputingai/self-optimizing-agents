# %%
import json 
import pandas as pd

# %%
import os
from pathlib import Path

print("cwd:", Path.cwd())
print("files here:", os.listdir(Path.cwd()))

print("cwd:", os.getcwd())
print("files here:", os.listdir(os.getcwd()))
print("up one:", os.listdir(os.path.join(os.getcwd(), "..")))
# Out:
# cwd: c:\Users\Dee\root\Projects\dev\graphgeeks-lab\odsc-agentic-ai-summit-2025
# files here: ['.env', '.git', '.gitignore', '.venv', 'create_dataset.py', 'data', 'demo', 'fhir_kuzu_db', 'format_json.py', 'process_fhir_data.ipynb', 'process_fhir_data.py', 'pyproject.toml', 'README.md', 'src', 'uv.lock']
# cwd: c:\Users\Dee\root\Projects\dev\graphgeeks-lab\odsc-agentic-ai-summit-2025
# files here: ['.env', '.git', '.gitignore', '.venv', 'create_dataset.py', 'data', 'demo', 'fhir_kuzu_db', 'format_json.py', 'process_fhir_data.ipynb', 'process_fhir_data.py', 'pyproject.toml', 'README.md', 'src', 'uv.lock']
# up one: ['.venv', 'asknews', 'awesome-graph-universe', 'baml-for-graph-101', 'demo_db', 'graph-algorithms', 'graph-explorer', 'graphfaker', 'odsc-agentic-ai-summit-2025', 'project-proposals', 'roadmap', 'test']

# %%
# Load the JSON array
print("Loading data from ./data/fhir_v2.jsonl")
with open('./data/fhir_v2.jsonl', 'r') as f:
    bundles = json.load(f)
# Out:
# Loading data from ./data/fhir_v2.jsonl

# %%
records = []

for bundle in bundles:
    bundle_id = bundle.get('id')
    for entry in bundle.get("entry", []):
        r = entry.get("resource", {})
        rec = {
            "bundle_id": bundle_id,
            "resourceType": r.get("resourceType"),
            "resource_id": r.get("id"),
            **r
        }
        records.append(rec)



df = pd.json_normalize(records)

# %%
# show all rows
pd.set_option("display.max_rows", None)
# show all columns
pd.set_option("display.max_columns", None)
# don’t truncate column contents
pd.set_option("display.max_colwidth", None)
# widen the “page” so it doesn’t wrap as much
pd.set_option("display.width", 1000)

# now display your DataFrame in full
from IPython.display import display

# %%
df.columns
# Out:
# Index(['bundle_id', 'resourceType', 'resource_id', 'id', 'name', 'telecom',
#        'gender', 'birthDate', 'address', 'multipleBirthBoolean',
#        'communication', 'maritalStatus.coding', 'maritalStatus.text', 'status',
#        'type', 'participant', 'period', 'serviceProvider', 'class.system',
#        'class.code', 'subject.reference', 'subject.display', 'clinicalStatus',
#        'verificationStatus', 'code', 'onsetDateTime', 'recordedDate',
#        'clinicalStatus.coding', 'verificationStatus.coding', 'code.coding',
#        'code.text', 'category', 'effectiveDateTime', 'issued', 'valueQuantity',
#        'occurrenceDateTime', 'primarySource', 'vaccineCode.coding',
#        'vaccineCode.text', 'patient.reference', 'encounter.reference',
#        'maritalStatus', 'deceasedDateTime', 'valueQuantity.value',
#        'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code',
#        'component', 'valueCodeableConcept', 'criticality', 'performedPeriod',
#        'reasonReference', 'active', 'reasonCode', 'abatementDateTime',
#        'occurrenceString', 'period.start', 'period.end',
#        'serviceProvider.reference', 'serviceProvider.display',
#        'performedPeriod.start', 'performedPeriod.end', 'reaction',
#        'multipleBirthInteger', 'valueCodeableConcept.coding',
#        'valueCodeableConcept.text', 'hospitalization',
#        'hospitalization.dischargeDisposition.coding',
#        'hospitalization.dischargeDisposition.text', 'valueString'],
#       dtype='object')

# %%
df['name'][2]
# Out:
# [{'use': 'official',
#   'family': 'Bashirian',
#   'given': ['Hobert', 'Armand'],
#   'prefix': ['Mr.']}]

# %%
df['address'][2]
# Out:
# [{'line': ['767 Windler Well'],
#   'city': 'Easthampton',
#   'state': 'Massachusetts',
#   'postalCode': '01027',
#   'country': 'US'}]

# %%
df['maritalStatus'][2]
# Out:
# np.float64(nan)

# %%
df_exp = df.explode('name').explode('address').reset_index(drop=True)

# %%
name_cols = pd.json_normalize(df_exp["name"])
#    for 'address'
addr_cols = pd.json_normalize(df_exp["address"])

# %%
df_clean = (
    df_exp
    .drop(columns=["name", "address"])
    .join([name_cols.add_prefix("name."), addr_cols.add_prefix("address.")])
)

# %%
print(df_clean.columns.tolist())
print(df_clean.head())
# Out:
# ['bundle_id', 'resourceType', 'resource_id', 'id', 'telecom', 'gender', 'birthDate', 'multipleBirthBoolean', 'communication', 'maritalStatus.coding', 'maritalStatus.text', 'status', 'type', 'participant', 'period', 'serviceProvider', 'class.system', 'class.code', 'subject.reference', 'subject.display', 'clinicalStatus', 'verificationStatus', 'code', 'onsetDateTime', 'recordedDate', 'clinicalStatus.coding', 'verificationStatus.coding', 'code.coding', 'code.text', 'category', 'effectiveDateTime', 'issued', 'valueQuantity', 'occurrenceDateTime', 'primarySource', 'vaccineCode.coding', 'vaccineCode.text', 'patient.reference', 'encounter.reference', 'maritalStatus', 'deceasedDateTime', 'valueQuantity.value', 'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code', 'component', 'valueCodeableConcept', 'criticality', 'performedPeriod', 'reasonReference', 'active', 'reasonCode', 'abatementDateTime', 'occurrenceString', 'period.start', 'period.end', 'serviceProvider.reference', 'serviceProvider.display', 'performedPeriod.start', 'performedPeriod.end', 'reaction', 'multipleBirthInteger', 'valueCodeableConcept.coding', 'valueCodeableConcept.text', 'hospitalization', 'hospitalization.dischargeDisposition.coding', 'hospitalization.dischargeDisposition.text', 'valueString', 'name.use', 'name.family', 'name.given', 'name.prefix', 'name.suffix', 'address.line', 'address.city', 'address.state', 'address.postalCode', 'address.country']
#   bundle_id resourceType resource_id id  \
# 0         1      Patient           1  1
# 1         1    Encounter           1  1
# 2         1      Patient           1  1
# 3         1    Condition           1  1
# 4         1    Condition           2  2
#
#                                              telecom gender   birthDate  \
# 0  [{'system': 'phone', 'value': '555-124-9334', ...   male        None
# 1                                                NaN    NaN         NaN
# 2                                               None   None  1988-11-12
# 3                                                NaN    NaN         NaN
# 4                                                NaN    NaN         NaN
#
#   multipleBirthBoolean                                      communication  \
# 0                False  [{'language': {'coding': [{'system': 'urn:ietf...
# 1                  NaN                                                NaN
# 2                False  [{'language': {'coding': [{'system': 'urn:ietf...
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
#
#                                 maritalStatus.coding  ...  name.use  \
# 0  [{'system': 'http://terminology.hl7.org/CodeSy...  ...  official
# 1                                                NaN  ...       NaN
# 2  [{'system': 'http://terminology.hl7.org/CodeSy...  ...  official
# 3                                                NaN  ...       NaN
# 4                                                NaN  ...       NaN
#
#   name.family        name.given name.prefix  name.suffix        address.line  \
# 0     Corkery   [Rudolf, Nolan]       [Mr.]          NaN  [983 Gutmann Burg]
# 1         NaN               NaN         NaN          NaN                 NaN
# 2   Bashirian  [Hobert, Armand]       [Mr.]          NaN  [767 Windler Well]
# 3         NaN               NaN         NaN          NaN                 NaN
# 4         NaN               NaN         NaN          NaN                 NaN
#
#   address.city  address.state address.postalCode address.country
# 0       Boston  Massachusetts              02111              US
# 1          NaN            NaN                NaN             NaN
# 2  Easthampton  Massachusetts              01027              US
# 3          NaN            NaN                NaN             NaN
# 4          NaN            NaN                NaN             NaN
#
# [5 rows x 78 columns]

# %%
def safe_join(x):
    if isinstance(x, list):
        return " ".join(x)
    return x


# apply to your two columns
df_clean["given_names"]    = df_clean["name.given"].apply(safe_join)
df_clean["street_address"] = df_clean["address.line"].apply(safe_join)

# %%
df_clean['given_names'].head(10)
# Out:
# 0     Rudolf Nolan
# 1              NaN
# 2    Hobert Armand
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7      Sonia María
# 8      Asa Sherman
# 9              NaN
# Name: given_names, dtype: object

# %%
# 3) Build the full_address and full_name columns
df_clean["full_address"] = (
    df_clean["street_address"]
    + ", "
    + df_clean["address.postalCode"].str.strip()
    + " "
    + df_clean["address.city"].str.strip()
).str.replace(r"\s+,", ",", regex=True)  # tidy up stray spaces before commas

df_clean["full_name"] = (
    df_clean["given_names"]
    + " "
    + df_clean["name.family"].str.strip()
).str.replace(r"\s+", " ", regex=True)

# %%
df_clean["full_address"].head(10)
# Out:
# 0         983 Gutmann Burg, 02111 Boston
# 1                                    NaN
# 2    767 Windler Well, 01027 Easthampton
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7          130 Rempel Vale, 02111 Boston
# 8           698 Kunde Spur, 02026 Dedham
# 9                                    NaN
# Name: full_address, dtype: object

# %%
counts = df_clean[["full_address","full_name"]].count()
print(counts)
# Out:
# full_address    2169
# full_name       3298
# dtype: int64

# %%
# 2) Individually, checking for non-null and non-empty strings
street_count = df_clean["full_address"].notna().sum()
given_count  = df_clean["full_name"].notna().sum()
print(f"full_address appears in {street_count} rows")
print(f"full_name appears in  {given_count} rows")

# 3) If you want to be sure you’re not counting blank strings:
street_count = df_clean["full_address"].str.strip().ne("").sum()
given_count  = df_clean["full_name"].str.strip().ne("").sum()

# 4) If you instead want the frequency of each distinct value:
print(df_clean["full_address"].value_counts().head())
print(df_clean["full_name"].value_counts().head())
# Out:
# full_address appears in 2169 rows
# full_name appears in  3298 rows
# full_address
# 881 Main Street, 01420 Fitchburg         11
# 200 MAY ST, 027035520 SOUTH ATTLEBORO    10
# 170 GOVERNORS AVE, 021763225 MELROSE      9
# 41 & 45 MALL ROAD, 019602901 PEABODY      9
# 365 EAST ST, 018761950 TEWKSBURY          8
# Name: count, dtype: int64
# full_name
# Alysha Koch         6
# Latoyia Lindgren    5
# Houston Funk        5
# Alex Satterfield    5
# Bennett Rippin      5
# Name: count, dtype: int64

# %%
# 1) Compute counts
addr_counts  = df_clean["full_address"].value_counts()
name_counts  = df_clean["full_name"].value_counts()

# 2) Identify the values that occur more than once
dupe_addrs = addr_counts[addr_counts > 1].index.tolist()
dupe_names = name_counts[name_counts > 1].index.tolist()

# 3a) Filter rows that share a duplicate address
df_addr_dups = df_clean[df_clean["full_address"].isin(dupe_addrs)]
print("Addresses seen >1 times:")
print(df_addr_dups["full_address"].value_counts().head())

# 3b) Filter rows that share a duplicate name
df_name_dups = df_clean[df_clean["full_name"].isin(dupe_names)]
print("\nNames seen >1 times:")
print(df_name_dups["full_name"].value_counts().head())

# 4) If you want rows where *both* name and address are duplicated together
df_both_dups = (
    df_clean
    .duplicated(subset=["full_name","full_address"], keep=False)
)
df_pair_dups = df_clean[df_both_dups]
print("\nRows where (full_name, full_address) pair is repeated:")
print(df_pair_dups[["full_name","full_address"]].drop_duplicates().head())
# Out:
# Addresses seen >1 times:
# full_address
# 881 Main Street, 01420 Fitchburg         11
# 200 MAY ST, 027035520 SOUTH ATTLEBORO    10
# 41 & 45 MALL ROAD, 019602901 PEABODY      9
# 170 GOVERNORS AVE, 021763225 MELROSE      9
# 14 PROSPECT STREET, 015681431 UPTON       8
# Name: count, dtype: int64
#
# Names seen >1 times:
# full_name
# Alysha Koch         6
# Bennett Rippin      5
# Maryann Hintz       5
# Carisa Kutch        5
# Latoyia Lindgren    5
# Name: count, dtype: int64
#
# Rows where (full_name, full_address) pair is repeated:
#          full_name                               full_address
# 1              NaN                                        NaN
# 26  Eldora Langosh                                        NaN
# 37        Wes King                                        NaN
# 74             NaN           881 Main Street, 01420 Fitchburg
# 83             NaN  8 SHIPWAY PL # C-8, 021294301 CHARLESTOWN

# %%
# exact match
addr = "881 Main Street, 01420 Fitchburg"
df_fitchburg = df_clean[df_clean["full_address"] == addr]

# print(df_fitchburg.shape)
# print(df_fitchburg)

df_fitchburg
# Out:
#      bundle_id  resourceType resource_id id  \
# 74           1  Organization           1  1
# 684          1  Practitioner           1  1
# 1459         1  Practitioner           1  1
# 1460         1  Organization           1  1
# 4678         1  Organization           1  1
# 5043         1  Organization           1  1
# 7127         1  Practitioner           1  1
# 7309         1  Organization           1  1
# 7624         1  Practitioner           1  1
# 7625         1  Organization           1  1
# 9747         1  Organization           2  2
#
#                                                 telecom gender birthDate  \
# 74                                                 None    NaN       NaN
# 684                                                None   male       NaN
# 1459  [{'system': 'email', 'value': 'Ted955.Reilly98...   male       NaN
# 1460                                               None    NaN       NaN
# 4678  [{'system': 'phone', 'value': '978-342-9781 Or...    NaN       NaN
# 5043  [{'system': 'phone', 'value': '978-342-9781 Or...    NaN       NaN
# 7127  [{'system': 'email', 'value': 'Ted955.Reilly98...   male       NaN
# 7309  [{'system': 'phone', 'value': '978-342-9781 Or...    NaN       NaN
# 7624  [{'system': 'email', 'value': 'Ted955.Reilly98...   None       NaN
# 7625                                               None    NaN       NaN
# 9747  [{'system': 'phone', 'value': '978-342-9781 Or...    NaN       NaN
#
#      multipleBirthBoolean communication maritalStatus.coding  ... name.suffix  \
# 74                    NaN           NaN                  NaN  ...         NaN
# 684                   NaN           NaN                  NaN  ...         NaN
# 1459                  NaN           NaN                  NaN  ...         NaN
# 1460                  NaN           NaN                  NaN  ...         NaN
# 4678                  NaN           NaN                  NaN  ...         NaN
# 5043                  NaN           NaN                  NaN  ...         NaN
# 7127                  NaN           NaN                  NaN  ...         NaN
# 7309                  NaN           NaN                  NaN  ...         NaN
# 7624                  NaN           NaN                  NaN  ...         NaN
# 7625                  NaN           NaN                  NaN  ...         NaN
# 9747                  NaN           NaN                  NaN  ...         NaN
#
#          address.line address.city address.state  address.postalCode  \
# 74    881 Main Street    Fitchburg            MA               01420
# 684   881 Main Street    Fitchburg            MA               01420
# 1459  881 Main Street    Fitchburg            MA               01420
# 1460  881 Main Street    Fitchburg            MA               01420
# 4678  881 Main Street    Fitchburg            MA               01420
# 5043  881 Main Street    Fitchburg            MA               01420
# 7127  881 Main Street    Fitchburg            MA               01420
# 7309  881 Main Street    Fitchburg            MA               01420
# 7624  881 Main Street    Fitchburg            MA               01420
# 7625  881 Main Street    Fitchburg            MA               01420
# 9747  881 Main Street    Fitchburg            MA               01420
#
#       address.country given_names   street_address  \
# 74                 US         NaN  881 Main Street
# 684                US         NaN  881 Main Street
# 1459               US         Ted  881 Main Street
# 1460               US         NaN  881 Main Street
# 4678               US         NaN  881 Main Street
# 5043               US         NaN  881 Main Street
# 7127               US         Ted  881 Main Street
# 7309               US         NaN  881 Main Street
# 7624               US         Ted  881 Main Street
# 7625               US         NaN  881 Main Street
# 9747               US         NaN  881 Main Street
#
#                           full_address   full_name
# 74    881 Main Street, 01420 Fitchburg         NaN
# 684   881 Main Street, 01420 Fitchburg         NaN
# 1459  881 Main Street, 01420 Fitchburg  Ted Reilly
# 1460  881 Main Street, 01420 Fitchburg         NaN
# 4678  881 Main Street, 01420 Fitchburg         NaN
# 5043  881 Main Street, 01420 Fitchburg         NaN
# 7127  881 Main Street, 01420 Fitchburg  Ted Reilly
# 7309  881 Main Street, 01420 Fitchburg         NaN
# 7624  881 Main Street, 01420 Fitchburg  Ted Reilly
# 7625  881 Main Street, 01420 Fitchburg         NaN
# 9747  881 Main Street, 01420 Fitchburg         NaN
#
# [11 rows x 82 columns]

# %%
# show all rows
pd.set_option("display.max_rows", None)
# show all columns
pd.set_option("display.max_columns", None)
# don’t truncate column contents
pd.set_option("display.max_colwidth", None)
# widen the “page” so it doesn’t wrap as much
pd.set_option("display.width", 1000)

# now display your DataFrame in full
from IPython.display import display
display(df_fitchburg)
# Out:
#      bundle_id  resourceType resource_id id                                                                        telecom gender birthDate multipleBirthBoolean communication maritalStatus.coding maritalStatus.text status                                                                                                                                                                    type participant  period  serviceProvider class.system class.code subject.reference subject.display  clinicalStatus  verificationStatus  code onsetDateTime recordedDate clinicalStatus.coding verificationStatus.coding code.coding code.text category effectiveDateTime issued  valueQuantity occurrenceDateTime primarySource vaccineCode.coding vaccineCode.text patient.reference encounter.reference  maritalStatus deceasedDateTime  valueQuantity.value valueQuantity.unit valueQuantity.system valueQuantity.code component  valueCodeableConcept criticality  performedPeriod reasonReference active reasonCode  \
# 74           1  Organization           1  1                                                                           None    NaN       NaN                  NaN           NaN                  NaN                NaN    NaN  [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem
# 7625               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN      NaN         NaN        NaN         NaN         NaN  881 Main Street    Fitchburg            MA              01420              US         NaN  881 Main Street  881 Main Street, 01420 Fitchburg         NaN
# 9747               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN      NaN         NaN        NaN         NaN         NaN  881 Main Street    Fitchburg            MA              01420              US         NaN  881 Main Street  881 Main Street, 01420 Fitchburg         NaN

# %%
# 0) Define the set of types to ignore
ignore_types = {"Practitioner", "Organization"}

# 1) Filter out those rows up front
df_patients = df_clean[~df_clean["resourceType"].isin(ignore_types)]

# 2) Compute address counts on that filtered set
addr_counts = df_patients["full_address"].value_counts()

# 3) Pick only the addresses seen more than once
dupe_addrs = addr_counts[addr_counts > 1].index.tolist()

# 4) Subset to just those duplicate addresses
df_addr_dups = df_patients[df_patients["full_address"].isin(dupe_addrs)]

# 5) Display the top ones
print("Addresses (excluding Practitioner & Organization) seen >1 times:")
print(df_addr_dups["full_address"].value_counts().head())
# Out:
# Addresses (excluding Practitioner & Organization) seen >1 times:
# full_address
# 776 Bergstrom Wall, 02451 Waltham                   4
# 642 Glover Junction Suite 70, 01532 Northborough    4
# 549 Dare Pathway Unit 28, 00000 Medway              4
# 1040 Fay Corner Suite 97, 02128 Boston              4
# 431 Vandervort Neck, 01030 Agawam                   4
# Name: count, dtype: int64

# %%
# exact match
addr = "776 Bergstrom Wall, 02451 Waltham"
df_waltham = df_clean[df_clean["full_address"] == addr]


df_waltham
# Out:
#      bundle_id resourceType resource_id id                                                        telecom  gender   birthDate multipleBirthBoolean                                                                                                                                          communication                                                                                       maritalStatus.coding maritalStatus.text status type participant  period  serviceProvider class.system class.code subject.reference subject.display  clinicalStatus  verificationStatus  code onsetDateTime recordedDate clinicalStatus.coding verificationStatus.coding code.coding code.text category effectiveDateTime issued  valueQuantity occurrenceDateTime primarySource vaccineCode.coding vaccineCode.text patient.reference encounter.reference  maritalStatus deceasedDateTime  valueQuantity.value valueQuantity.unit valueQuantity.system valueQuantity.code component  valueCodeableConcept criticality  \
# 2776         1      Patient           1  1  [{'system': 'phone', 'value': '555-137-8673', 'use': 'home'}]  female  1983-05-03                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]                                                                                                        NaN                NaN    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN
# 2777         1      Patient           1  1  [{'system': 'phone', 'value': '555-137-8673', 'use': 'home'}]  female  1983-05-03                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]                                                                                                        NaN                NaN    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN
# 6507         1      Patient           1  1  [{'system': 'phone', 'value': '555-137-8673', 'use': 'home'}]    None  1983-05-03                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'Married'}]            Married    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN
# 6508         1      Patient           1  1  [{'system': 'phone', 'value': '555-137-8673', 'use': 'home'}]    None  1983-05-03                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'Married'}]            Married    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN
#
#       performedPeriod reasonReference active reasonCode abatementDateTime occurrenceString period.start period.end serviceProvider.reference serviceProvider.display performedPeriod.start performedPeriod.end reaction  multipleBirthInteger valueCodeableConcept.coding valueCodeableConcept.text  hospitalization hospitalization.dischargeDisposition.coding hospitalization.dischargeDisposition.text valueString  name.use name.family    name.given name.prefix name.suffix        address.line address.city  address.state address.postalCode address.country   given_names      street_address                       full_address              full_name
# 2776              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN  official       Doyle  Melany Renda      [Mrs.]         NaN  776 Bergstrom Wall      Waltham  Massachusetts              02451              US  Melany Renda  776 Bergstrom Wall  776 Bergstrom Wall, 02451 Waltham     Melany Renda Doyle
# 2777              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN    maiden    Tremblay          None      [Mrs.]         NaN  776 Bergstrom Wall      Waltham  Massachusetts              02451              US          None  776 Bergstrom Wall  776 Bergstrom Wall, 02451 Waltham                    NaN
# 6507              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN  official       Doyle  Melany Renda      [Mrs.]         NaN  776 Bergstrom Wall      Waltham  Massachusetts              02451              US  Melany Renda  776 Bergstrom Wall  776 Bergstrom Wall, 02451 Waltham     Melany Renda Doyle
# 6508              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN    maiden    Tremblay  Melany Renda      [Mrs.]         NaN  776 Bergstrom Wall      Waltham  Massachusetts              02451              US  Melany Renda  776 Bergstrom Wall  776 Bergstrom Wall, 02451 Waltham  Melany Renda Tremblay

# %%
# Group by full_address and list the resourceType/id pairs
grouped = (
    df_addr_dups
      .groupby("full_address")
      .apply(lambda g: list(zip(g["resourceType"], g["resource_id"])))
)

for addr, resources in grouped.items():
    print(f"\n{addr} (seen {len(resources)} times):")
    for rtype, rid in resources:
        print(f"  - {rtype}/{rid}")
# Out:
# 1006 Block Heights Unit 26, 00000 Mansfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1006 Reynolds Pathway Unit 63, 02638 Dennis (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 101 Howell Branch, 01540 Oxford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1010 Prohaska Row Suite 24, 01469 Townsend (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1011 Hartmann Lane, 01230 Great Barrington (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1011 Ratke Way, 02364 Kingston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1012 DuBuque Mission Suite 38, 00000 Grafton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1016 Heathcote Mall, 00000 Billerica (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1017 Legros Route, 02748 New Bedford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1018 Borer Vista Unit 1, 02148 Malden (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1018 Kemmer Rapid Apt 41, 02467 Brookline (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1022 Beahan Lodge, 02052 Medfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1023 Stark Spur, 02176 Melrose (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1025 MacGyver Club Apt 5, 02067 Sharon (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1035 Halvorson Park, 02149 Everett (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 104 Kertzmann Gate Unit 59, 01605 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1040 Fay Corner Suite 97, 02128 Boston (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 1050 Thompson Mill Unit 25, 02743 New Bedford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1053 Ryan Trace, 02180 Stoneham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1055 Bayer Branch, 02720 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1057 Kreiger Club, 01440 Gardner (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 1059 O'Hara Gateway Suite 74, 02532 Bourne (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1068 Heidenreich Trailer Apt 78, 02149 Everett (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1071 Beier Center Apt 8, 00000 Dracut (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1072 Hand Rest, 01801 Reading (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1072 Mosciski Mall, 01020 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1073 Champlin Light, 00000 Seekonk (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1073 Gutmann Forge, 01602 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1073 Jacobson Street Apt 59, 00000 Seekonk (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 1074 Bahringer Fort, 02451 Waltham (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 1075 Cruickshank Extension, 01970 Salem (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 108 Bergnaum Green, 00000 Millbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1087 Ankunding Way Apt 36, 01535 North Brookfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1093 Grady Forge, 02108 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 1094 Grant Terrace Unit 67, 01843 Lawrence (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 113 Simonis Parade Unit 16, 02790 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 113 Wolf Alley Suite 39, 02536 Teaticket (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 114 Boehm Esplanade Suite 21, 01040 Holyoke (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 114 Collins Dale, 00000 Dalton (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 114 Klein Trail Suite 22, 01420 Leominster (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 114 Shanahan Rue, 01801 Reading (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 115 Balistreri Gateway, 00000 North Attleborough (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 115 Dicki Forge Suite 89, 02780 Taunton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 122 Mills Manor, 00000 Norwell (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 123 Spinka Extension, 02364 Kingston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 130 Upton Pathway, 01610 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 132 Weimann Wall, 02301 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 133 Kiehn Underpass, 02446 Brookline (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 136 Buckridge Bridge, 02360 Plymouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 138 Koss Gateway Unit 12, 01851 Lowell (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 140 Rodriguez Landing, 02149 Everett (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 144 Glover Passage Suite 98, 01880 Wakefield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 151 Keeling Junction, 02664 South Yarmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 152 Littel Byway Unit 26, 02180 Stoneham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 154 VonRueden Club Suite 76, 00000 Ashland (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 158 Roberts Approach Apt 51, 02723 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 167 Rath Estate, 02215 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 169 Hartmann Route Suite 65, 02861 Attleboro (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 172 Herzog Rue Unit 29, 01008 Blandford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 174 Padberg Neck, 02540 Falmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 175 Brekke Quay Unit 44, 00000 East Longmeadow (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 175 Funk Ramp, 00000 Raynham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 176 Gorczany Trail Suite 76, 00000 Seekonk (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 181 Vandervort Grove, 00000 North Attleborough (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 182 Leffler Mill Unit 4, 02724 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 187 Parker Rest, 01970 Salem (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 192 Bartoletti Viaduct, 00000 Bernardston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 197 Cummings Bay Suite 70, 00000 Tewksbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 199 Brekke Bay, 02351 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 207 Okuneva Light Apt 90, 00000 Dartmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 215 Oberbrunner Approach Unit 50, 01085 Westfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 216 Walter Fort, 02368 Randolph (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 217 Rodriguez Row, 00000 Amherst (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 218 Hammes Esplanade, 02124 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 220 Wuckert Orchard, 02108 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 221 Gleichner Dale Apt 28, 00000 Hampden (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 224 Ruecker Ranch Apt 22, 01609 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 225 Hane Haven Unit 76, 01008 Blandford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 225 Kozey Light, 01844 Methuen (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 225 Swift Estate, 02460 Newton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 227 McKenzie Quay Suite 0, 00000 Natick (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 233 Boyer Well, 02536 Teaticket (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 237 Grant Harbor, 02638 Dennis (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 237 Koelpin Lane, 01902 Lynn (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 240 Bartoletti Gate, 00000 Ludlow (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 248 Blanda Mall, 00000 Yarmouth (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 248 MacGyver Harbor, 00000 Chelmsford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 248 Wunsch Throughway Unit 51, 01540 Oxford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 249 Turcotte Gardens Apt 22, 00000 West Tisbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 250 Brown Terrace, 01040 Holyoke (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 251 McGlynn Bay, 02540 Falmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 252 Bahringer Branch, 02451 Waltham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 252 Towne Road, 02134 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 257 Moore Parade, 00000 Shrewsbury (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 259 Adams Ville Unit 69, 02110 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 260 Mohr Ferry, 01001 Agawam (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 262 Fritsch Mall, 02050 Marshfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 262 Legros Wynd, 02747 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 270 Murphy Harbor Apt 63, 01930 Gloucester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 271 Weber Frontage road Suite 61, 01844 Methuen (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 274 Paucek Divide Unit 26, 02536 Teaticket (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 276 Konopelski Walk Apt 24, 00000 Weweantic (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 277 Funk Parade Apt 41, 01550 Southbridge (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 279 Kub Course, 01810 Andover (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 280 Marks Divide Unit 34, 00000 Rehoboth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 281 Mueller Mission Suite 79, 00000 Newbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 281 Stehr Green, 00000 Dighton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 283 Bode Parade Apt 7, 01107 Springfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 285 Nolan Mission Suite 99, 00000 Canton (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 290 Adams Glen Suite 87, 00000 Hamilton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 291 Mohr Promenade, 01540 Oxford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 292 Dietrich Viaduct Suite 24, 01940 Wakefield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 294 Hamill Camp, 01913 Amesbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 297 Bergnaum Vista Unit 4, 00000 Stoughton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 297 Bruen Neck Apt 42, 01550 Southbridge (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 297 Lakin Street Apt 49, 00000 Mattapoisett Center (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 297 Schowalter Ranch, 00000 Seekonk (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 304 Effertz Bridge, 02118 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 305 Ruecker Passage, 01060 Northampton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 306 Maggio Avenue, 01201 Pittsfield (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 306 Will Flat, 01022 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 309 Casper Key Apt 47, 02655 Barnstable (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 311 Stokes Terrace Unit 81, 00000 Dracut (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 312 Kihn Skyway, 00000 North Andover (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 313 Reichel Light Unit 57, 00000 Amherst (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 314 Lang Passage, 01106 Longmeadow (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 314 Lind Forge Unit 61, 01027 Easthampton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 317 Williamson Pathway Suite 53, 01749 Hudson (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 318 Hudson Extension, 00000 Yarmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 320 Russel Light Suite 82, 01757 Milford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 327 Cruickshank Tunnel Unit 40, 02114 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 327 Kirlin Neck, 00000 Dartmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 327 Zulauf Extension Unit 21, 02445 Brookline (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 329 Moen Fort Unit 22, 01602 Worcester (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 332 Beahan Corner Suite 87, 01890 Woburn (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 337 Towne Gateway Unit 55, 00000 Wareham Center (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 337 Wiza Bridge, 02115 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 339 Konopelski Route Apt 8, 02481 Wellesley (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 340 Wunsch Frontage road Suite 98, 02134 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 341 Marvin Neck, 02638 Dennis (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 345 Abbott Station Suite 83, 02703 Attleboro (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 346 Gulgowski Pathway, 02052 Medfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 347 Denesik Run Suite 75, 01902 Lynn (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 351 Cole Well Unit 56, 00000 Shrewsbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 354 Keeling Green, 01022 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 354 Kris Light, 02132 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 355 Lakin Road Apt 19, 02184 Braintree (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 355 Welch Knoll, 02351 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 357 Simonis Byway, 00000 Weweantic (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 363 Rippin Street Apt 12, 02472 Waltham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 365 Crooks Meadow Unit 27, 02140 Somerville (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 365 Keebler Overpass Suite 29, 01540 Oxford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 369 Senger Drive Apt 33, 02368 Holbrook (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 371 Weber Meadow, 02155 Malden (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 371 Witting Well Apt 23, 01085 Westfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 371 Wolff Boulevard Suite 97, 01810 Andover (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 372 Kautzer Trailer, 01060 Northampton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 372 Schultz Bridge Apt 95, 01030 Agawam (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 373 Daugherty Plaza Unit 53, 00000 Hamilton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 381 Labadie Walk Suite 81, 00000 Billerica (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 382 McCullough Run Suite 79, 01867 Reading (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 385 Ward Flat, 02121 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 389 Rowe Harbor Suite 94, 02120 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 394 Hauck View, 02118 Boston (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 399 Russel Wynd, 00000 West Newbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 400 Predovic Branch Unit 45, 02148 Malden (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 401 Bogisich Course, 02324 Bridgewater (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 401 Kuphal Rest Apt 4, 02115 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 402 Ward Branch, 01851 Lowell (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 403 Heathcote Rue Unit 60, 01107 Springfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 408 Smith Station Apt 58, 00000 Mendon (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 408 Tremblay Port, 01201 Pittsfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 412 Schroeder Highlands, 01940 Peabody (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 413 Anderson Manor, 01607 Worcester (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 413 Ebert Vista Unit 72, 00000 Swansea (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 417 Herzog View Unit 35, 02301 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 417 Weissnat Esplanade Unit 12, 02145 Medford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 419 Kovacek Avenue, 00000 Westwood (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 421 Pagac Burg Suite 15, 02130 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 422 Schowalter Spur Unit 62, 02203 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 424 Fisher Ferry Unit 40, 02066 Scituate (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 425 Heaney Corner, 01550 Southbridge (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 426 Stracke Passage Suite 47, 01810 Andover (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 427 Zulauf Byway, 00000 Marion Center (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 428 Bogan Extension, 02109 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 431 Sipes Glen Apt 43, 01370 Shelburne Falls (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 431 Vandervort Neck, 01030 Agawam (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 436 Morissette Gateway Unit 58, 00000 Norton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 449 Kuphal Mission Apt 0, 02210 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 452 Lockman Parade, 02746 New Bedford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 459 Raynor Harbor Apt 63, 01810 Andover (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 461 Swaniawski Light, 01915 Beverly (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 461 Witting Lane, 00000 Sudbury (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 462 Cole Grove Unit 95, 02532 Bourne (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 462 Mraz Gateway Unit 39, 02176 Melrose (seen 2 times):
#   - Patient/1
#   - Patient/1
#
#
seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 569 Wiegand Hollow Suite 56, 02141 Cambridge (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 570 Wiegand Skyway, 01013 Springfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 571 Smith Center Suite 89, 00000 Hanover (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 572 Feil Estate, 02215 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 575 Gottlieb Gateway, 01453 Leominster (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 578 Aufderhar Dam Unit 52, 00000 Worthington (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 578 Hagenes Annex, 02045 Hull (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 580 Feeney Village Apt 35, 02130 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 589 Mayer Esplanade, 01020 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 592 Kling Manor Unit 13, 02633 Chatham (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 594 Grady Mission Apt 64, 02108 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 599 Kirlin Plaza, 02120 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 599 Vandervort Annex, 02740 New Bedford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 600 Homenick Bypass Unit 4, 00000 Billerica (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 601 Bosco Bypass Suite 94, 02467 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 605 Emard Gate Suite 47, 01907 Salem (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 606 Lebsack Ferry, 00000 Wareham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 609 Davis Orchard, 02540 Falmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 611 Klein Drive Unit 96, 02492 Needham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 612 Weissnat Rest Apt 46, 02114 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 613 Bergnaum Approach, 00000 Rockland (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 613 Schulist Burg Suite 81, 02726 Somerset (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 615 Blick Crossing Apt 46, 02492 Wellesley (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 615 Block Well, 01040 Holyoke (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 619 Jaskolski Union Apt 98, 02568 Vineyard Haven (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 619 Morissette View, 02302 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 625 Rempel Rapid Unit 69, 00000 Millville (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 630 Tillman Lane Unit 60, 01040 Holyoke (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 642 Glover Junction Suite 70, 01532 Northborough (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 644 Dietrich Key, 00000 Billerica (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 644 Doyle Route, 01201 Pittsfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 644 Kohler Gardens Unit 38, 02302 Brockton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 654 Flatley Esplanade Suite 42, 00000 Cohasset (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 662 Wyman Wall, 01230 Great Barrington (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 664 Wolf Trafficway Suite 98, 00000 Rockland (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 667 Hackett Parade, 00000 Norton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 667 Hodkiewicz Burg Suite 47, 01040 Holyoke (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 670 Beahan Overpass Apt 78, 02721 Fall River (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 670 Smith Arcade Apt 88, 00000 Fairhaven (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 673 Bode Rest, 01301 Greenfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 673 Schmitt Junction Apt 70, 01013 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 674 Rowe Key, 00000 Plainville (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 677 Becker Ranch Apt 1, 01033 Granby (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 682 Reinger Lodge Suite 93, 00000 Canton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 683 Harvey Alley, 02120 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 688 Maggio Ramp, 01702 Framingham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 690 Kiehn Highlands, 02151 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 691 Schuster Trailer, 02861 Attleboro (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 692 Beer Junction, 01602 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 695 Rowe Ferry, 01841 Methuen (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 697 Erdman Gateway, 01801 Woburn (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 700 Oberbrunner Bay, 01940 Wakefield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 701 Pacocha Bypass Suite 11, 02324 Bridgewater (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 707 Halvorson Glen, 00000 Harwich (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 707 Wisoky Bypass, 02675 Yarmouth Port (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 710 Bernhard Well, 02467 Boston (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 711 Boehm Ranch, 00000 Northbridge (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 715 Kerluke Port Unit 40, 02110 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 717 Kovacek Divide, 00000 North Westport (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 720 Hahn Street Unit 8, 02019 Bellingham (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 724 Labadie Club Suite 11, 01867 Reading (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 724 VonRueden Grove Suite 54, 02114 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 727 Will Trace, 01108 Springfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 730 Rogahn Ramp, 02767 Taunton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 731 Haag Fort, 02019 Bellingham (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 731 Jaskolski Trafficway Suite 75, 00000 Wayland (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 732 Ullrich Gardens Apt 0, 01607 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 733 Schultz Glen, 01902 Lynn (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 733 Wyman Forge Unit 77, 02351 Abington (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 736 Jacobson Village Unit 11, 01040 Holyoke (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 736 Reynolds Fork Unit 99, 01020 Chicopee (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 739 Fahey Light Unit 66, 02132 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 741 McClure Annex, 00000 Westford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 744 Morar Avenue, 02561 Sagamore (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 747 Littel Club Unit 15, 02114 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 748 Turcotte Parade, 02126 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 756 Cartwright Tunnel Unit 33, 00000 Mattapoisett (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 757 Aufderhar Quay, 01907 Swampscott (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 758 Fisher Dale, 02038 Franklin (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 759 Price Station, 01606 Worcester (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 761 Keebler Rest Apt 73, 02126 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 762 Blick Quay, 00000 Billerica (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 767 Denesik Overpass, 01440 Gardner (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 776 Bergstrom Wall, 02451 Waltham (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 776 Kovacek Ferry, 02128 Boston (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 780 Kunze Mews Suite 54, 01201 Pittsfield (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 780 Nolan Pathway Apt 28, 01960 Peabody (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 781 Hansen Quay, 00000 Pembroke (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 784 O'Connell Neck, 02145 Medford (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 787 Wuckert Junction Unit 84, 01940 Wakefield (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 788 Brown Junction, 02144 Somerville (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 788 Daniel Club Unit 19, 01040 Holyoke (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 794 Wunsch Spur, 00000 North Westport (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 795 Johns Lodge Unit 54, 00000 Seekonk (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 795 Witting Loaf, 02780 Taunton (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 798 Baumbach Dam Apt 16, 02638 Dennis (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 799 Kshlerin Club, 02540 Falmouth (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 804 Prosacco Burg, 01852 Lowell (seen 2 times):
#   - Patient/1
#   - Patient/1
#
# 805 Schoen Trafficway, 00000 Grafton (seen 4 times):
#   - Patient/1
#   - Patient/1
#   - Patient/1
#   - Patient/1
#
# 806 Kemmer Run, 02554 Nantucket (seen 2 times):
#   - Patient/1
#   - Patient/1
#
#
DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: list(zip(g["resourceType"], g["resource_id"])))

# %%
# exact match
addr = "101 Howell Branch, 01540 Oxford"
df_oxford = df_clean[df_clean["full_address"] == addr]


df_oxford
# Out:
#      bundle_id resourceType resource_id id                                                        telecom gender   birthDate multipleBirthBoolean communication                                                                                       maritalStatus.coding maritalStatus.text status type participant  period  serviceProvider class.system class.code subject.reference subject.display  clinicalStatus  verificationStatus  code onsetDateTime recordedDate clinicalStatus.coding verificationStatus.coding code.coding code.text category effectiveDateTime issued  valueQuantity occurrenceDateTime primarySource vaccineCode.coding vaccineCode.text patient.reference encounter.reference  maritalStatus deceasedDateTime  valueQuantity.value valueQuantity.unit valueQuantity.system valueQuantity.code component  valueCodeableConcept criticality  performedPeriod reasonReference active reasonCode abatementDateTime occurrenceString period.start period.end serviceProvider.reference  \
# 3334         1      Patient           1  1  [{'system': 'phone', 'value': '555-225-3716', 'use': 'home'}]   None  1972-09-21                 None          None  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'Married'}]            Married    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN
# 3335         1      Patient           1  1  [{'system': 'phone', 'value': '555-225-3716', 'use': 'home'}]   None  1972-09-21                 None          None  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'Married'}]            Married    NaN  NaN         NaN     NaN              NaN          NaN        NaN               NaN             NaN             NaN                 NaN   NaN           NaN          NaN                   NaN                       NaN         NaN       NaN      NaN               NaN    NaN            NaN                NaN           NaN                NaN              NaN               NaN                 NaN            NaN              NaN                  NaN                NaN                  NaN                NaN       NaN                   NaN         NaN              NaN             NaN    NaN        NaN               NaN              NaN          NaN        NaN                       NaN
#
#      serviceProvider.display performedPeriod.start performedPeriod.end reaction  multipleBirthInteger valueCodeableConcept.coding valueCodeableConcept.text  hospitalization hospitalization.dischargeDisposition.coding hospitalization.dischargeDisposition.text valueString  name.use name.family         name.given name.prefix name.suffix       address.line address.city  address.state address.postalCode address.country        given_names     street_address                     full_address                  full_name
# 3334                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN  official     Kessler  Marquitta Lavonda      [Mrs.]         NaN  101 Howell Branch       Oxford  Massachusetts              01540              US  Marquitta Lavonda  101 Howell Branch  101 Howell Branch, 01540 Oxford  Marquitta Lavonda Kessler
# 3335                     NaN                   NaN                 NaN      NaN                   NaN                         NaN                       NaN              NaN                                         NaN                                       NaN         NaN    maiden      Murray  Marquitta Lavonda      [Mrs.]         NaN  101 Howell Branch       Oxford  Massachusetts              01540              US  Marquitta Lavonda  101 Howell Branch  101 Howell Branch, 01540 Oxford   Marquitta Lavonda Murray

# %%
import json
import polars as pl

# %%
# 1) Keep only one row per unique address
unique_addr = df_clean.drop_duplicates(subset="full_address")

# 2) List all states
states = sorted(unique_addr["address.state"].dropna().unique())
print("States in dataset:")
for s in states:
    print(f" - {s}")

# 3) Count unique states, cities, and postal codes
num_states       = len(states)
num_cities       = unique_addr["address.city"].dropna().nunique()
num_postal_codes = unique_addr["address.postalCode"].dropna().nunique()

print(f"\nNumber of unique states:     {num_states}")
print(f"Number of unique cities:     {num_cities}")
print(f"Number of unique post codes: {num_postal_codes}")
# Out:
# States in dataset:
#  - MA
#  - Massachusetts
#
# Number of unique states:     2
# Number of unique cities:     391
# Number of unique post codes: 484

# %%
# 1) Dedupe on the already-built full_address
unique_addr = df_clean.drop_duplicates(subset="full_address")

# 2) Normalize city and postalCode for counting
cities_norm       = unique_addr["address.city"].dropna().str.strip().str.lower()
postal_codes_norm = unique_addr["address.postalCode"].dropna().str.strip().str.lower()

# 3) Get unique (case-insensitive) lists
states = sorted(unique_addr["address.state"].dropna().unique())  # states usually already standardized
cities = sorted(cities_norm.unique())
zips   = sorted(postal_codes_norm.unique())

# 4) Print
print("States in dataset:")
for s in states:
    print(f" - {s}")

print(f"\nNumber of unique states:     {len(states)}")
print(f"Number of unique cities:     {len(cities)}")
print(f"Number of unique post codes: {len(zips)}")
# Out:
# States in dataset:
#  - MA
#  - Massachusetts
#
# Number of unique states:     2
# Number of unique cities:     300
# Number of unique post codes: 484

# %%
print(df_clean.columns)
# Out:
# Index(['bundle_id', 'resourceType', 'resource_id', 'id', 'telecom', 'gender', 'birthDate', 'multipleBirthBoolean', 'communication', 'maritalStatus.coding', 'maritalStatus.text', 'status', 'type', 'participant', 'period', 'serviceProvider', 'class.system', 'class.code', 'subject.reference', 'subject.display', 'clinicalStatus', 'verificationStatus', 'code', 'onsetDateTime', 'recordedDate', 'clinicalStatus.coding', 'verificationStatus.coding', 'code.coding', 'code.text', 'category', 'effectiveDateTime', 'issued', 'valueQuantity', 'occurrenceDateTime', 'primarySource', 'vaccineCode.coding', 'vaccineCode.text', 'patient.reference', 'encounter.reference', 'maritalStatus', 'deceasedDateTime', 'valueQuantity.value', 'valueQuantity.unit', 'valueQuantity.system', 'valueQuantity.code', 'component', 'valueCodeableConcept', 'criticality', 'performedPeriod', 'reasonReference', 'active', 'reasonCode', 'abatementDateTime', 'occurrenceString', 'period.start', 'period.end', 'serviceProvider.reference',
#        'serviceProvider.display', 'performedPeriod.start', 'performedPeriod.end', 'reaction', 'multipleBirthInteger', 'valueCodeableConcept.coding', 'valueCodeableConcept.text', 'hospitalization', 'hospitalization.dischargeDisposition.coding', 'hospitalization.dischargeDisposition.text', 'valueString', 'name.use', 'name.family', 'name.given', 'name.prefix', 'name.suffix', 'address.line', 'address.city', 'address.state', 'address.postalCode', 'address.country', 'given_names', 'street_address', 'full_address', 'full_name'],
#       dtype='object')

# %%
category_counts = df_clean["resourceType"].value_counts()
print(category_counts)
# Out:
# resourceType
# Patient               3435
# Encounter             2062
# Observation            902
# Procedure              893
# Condition              786
# Practitioner           698
# Organization           655
# Immunization           437
# AllergyIntolerance     365
# Name: count, dtype: int64

# %%
import json
import pandas as pd

# 1) Load your array of Bundles
with open("./data/fhir_v2.jsonl", "r", encoding="utf-8") as f:
    bundles = json.load(f)
# 2) Build rows: one dict per Bundle
rows = []
for b in bundles:
    row = {
        "bundle_id":   b["id"],
        "bundle_type": b.get("type"),
    }
    # collect IDs by resourceType
    for entry in b.get("entry", []):
        r = entry["resource"]
        col = f"{r['resourceType'].lower()}_ids"
        row.setdefault(col, []).append(r["id"])
    rows.append(row)

# 3) Create the DataFrame
df_bundles = pd.DataFrame(rows)

# 4) Ensure every *_ids column is a list (not NaN)
for col in df_bundles.columns:
    if col.endswith("_ids"):
        df_bundles[col] = df_bundles[col].apply(lambda x: x if isinstance(x, list) else [])

# %%
import json
import pandas as pd

# suppose bundles is a list of Bundle‐dicts
with open('./data/fhir_v2.jsonl', 'r', encoding='utf-8') as f:
    bundles = json.load(f)

records = []
for bundle_idx, bundle in enumerate(bundles, start=1):
    for entry in bundle.get("entry", []):
        r = entry.get("resource", {})
        rec = {
            "bundle_id": bundle_idx,            # use enumerate index
            "resourceType": r.get("resourceType"),
            "resource_id":   r.get("id"),
            **r
        }
        records.append(rec)

df_bundles = pd.json_normalize(records)

# Thanh759.Weber641@example.com

# %%
df_bundles.head(n=10)
# Out:
#    bundle_id  resourceType resource_id id                                                                                            name                                                        telecom  gender   birthDate                                                                                                                    address multipleBirthBoolean                                                                                                                                          communication                                                                                       maritalStatus.coding maritalStatus.text     status  type participant  period  serviceProvider                                      class.system class.code subject.reference           subject.display  clinicalStatus  verificationStatus  code              onsetDateTime recordedDate                                                                       clinicalStatus.coding  \
# 0          1       Patient           1  1     [{'use': 'official', 'family': 'Corkery', 'given': ['Rudolf', 'Nolan'], 'prefix': ['Mr.']}]  [{'system': 'phone', 'value': '555-124-9334', 'use': 'home'}]    male        None       [{'line': ['983 Gutmann Burg'], 'city': 'Boston', 'state': 'Massachusetts', 'postalCode': '02111', 'country': 'US'}]                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'M', 'display': 'Married'}]            Married        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN               NaN                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 1          1     Encounter           1  1                                                                                             NaN                                                            NaN     NaN         NaN                                                                                                                        NaN                  NaN                                                                                                                                                    NaN                                                                                                        NaN                NaN    unknown  None        None     NaN              NaN  http://terminology.hl7.org/CodeSystem/v3-ActCode        AMB         Patient/1  Mr. Rudolf Nolan Corkery             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 2          2       Patient           1  1  [{'use': 'official', 'family': 'Bashirian', 'given': ['Hobert', 'Armand'], 'prefix': ['Mr.']}]                                                           None    None  1988-11-12  [{'line': ['767 Windler Well'], 'city': 'Easthampton', 'state': 'Massachusetts', 'postalCode': '01027', 'country': 'US'}]                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]  [{'system': 'http://terminology.hl7.org/CodeSystem/v3-MaritalStatus', 'code': 'W', 'display': 'Widowed'}]            Widowed        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN               NaN                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 3          2     Condition           1  1                                                                                             NaN                                                            NaN     NaN         NaN                                                                                                                        NaN                  NaN                                                                                                                                                    NaN                                                                                                        NaN                NaN        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN         Patient/1                       NaN             NaN                 NaN   NaN  2014-02-03T00:38:02+01:00         None                                                                                         NaN
# 4          2     Condition           2  2                                                                                             NaN                                                            NaN     NaN         NaN                                                                                                                        NaN                  NaN                                                                                                                                                    NaN                                                                                                        NaN                NaN        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN         Patient/1                       NaN             NaN                 NaN   NaN  2008-01-12T01:09:00+01:00         None  [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical', 'code': 'active'}]
# 5          2   Observation           1  1                                                                                             NaN                                                            NaN     NaN         NaN                                                                                                                        NaN                  NaN                                                                                                                                                    NaN                                                                                                        NaN                NaN      final   NaN         NaN     NaN              NaN                                               NaN        NaN         Patient/1                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 6          3  Immunization           1  1                                                                                             NaN                                                            NaN     NaN         NaN                                                                                                                        NaN                  NaN                                                                                                                                                    NaN                                                                                                        NaN                NaN  completed   NaN         NaN     NaN              NaN                                               NaN        NaN               NaN                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 7          3       Patient           1  1     [{'use': 'official', 'family': 'Bañuelos', 'given': ['Sonia', 'María'], 'prefix': ['Ms.']}]                                                           None  female        None        [{'line': ['130 Rempel Vale'], 'city': 'Boston', 'state': 'Massachusetts', 'postalCode': '02111', 'country': 'US'}]                False                                     [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'es', 'display': 'Spanish'}], 'text': 'Spanish'}}]                                                                                                        NaN                NaN        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN               NaN                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
# 8          4       Patient           1  1        [{'use': 'official', 'family': 'Nolan', 'given': ['Asa', 'Sherman'], 'prefix': ['Mr.']}]  [{'system': 'phone', 'value': '555-216-4130', 'use': 'home'}]    None  1945-05-06         [{'line': ['698 Kunde Spur'], 'city': 'Dedham', 'state': 'Massachusetts', 'postalCode': '02026', 'country': 'US'}]                False  [{'language': {'coding': [{'system': 'urn:ietf:bcp:47', 'code': 'en-US', 'display': 'English (United States)'}], 'text': 'English (United States)'}}]                                                                                                        NaN                NaN        NaN   NaN         NaN     NaN              NaN                                               NaN        NaN               NaN                       NaN             NaN                 NaN   NaN                        NaN          NaN                                                                                         NaN
